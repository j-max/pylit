# %%
# %load_ext autoreload
# %autoreload 2
# imports
import sys

import nltk

# Jupyter notebook paths are relative to the file location
# add the path to the root folder
sys.path.append("../src")

from documents import Document
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nltk.download('punkt_tab')
nltk.downloader.download('vader_lexicon')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/johnbarry/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/johnbarry/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/johnbarry/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
journal_doc = Document(
    read_in_file=True,
    path_to_document='../sample_texts/sample_journal.txt', 
    create_sentences=True

)

# %%
journal_doc.describe()
# Out:
#              doc_name  word_count  sentence_count  \
# 0  sample_journal.txt        1338              70
#
#                                     longest_sentence most_common_word  \
# 0  Date: March 10, 2023  Today’s Tasks:  Write bl...                i
#
#    question_count  avg sentiment
# 0               1       0.297531
# {'doc_name': ['sample_journal.txt'],
#  'word_count': [1338],
#  'sentence_count': [70],
#  'longest_sentence': ['Date: March 10, 2023  Today’s Tasks:  Write blog post on journaling examples Schedule dentist appointment Complete 30-minute yoga session Attend team meeting at 2pm Respond to client emails Notes:  Remember to follow up with Sarah about the new project proposal Need to buy groceries after work – add to tomorrow’s task list The idea of my next art project keeps coming up.'],
#  'most_common_word': ['i'],
#  'question_count': [1],
#  'avg sentiment': [0.2975314285714286]}

# %%
journal_doc.document_string
# Out:
# 'Date: March 9, 2023  Today, I am grateful for:  The warm cup of coffee I had this morning that helped me start my day off right. The beautiful sunrise I saw on my way to work that reminded me of the beauty in nature. The supportive friends and family in my life who are always there for me when I need them. The fact that I have a job that allows me to support myself and pursue my passions. The opportunity to take a walk outside during my lunch break and soak up some sunshine and fresh air. Writing down these things I am grateful for helps me appreciate the positive aspects of my life and shifts my focus away from negativity. It reminds me that even on the toughest days, there are still things to be grateful for and that there is always something to look forward to tomorrow.  July 12, 2022  Location: Paris, France  Today was my first day in Paris and it was absolutely magical. I woke up early and headed straight to the Eiffel Tower to catch the sunrise. The view from the top was breat
# ...

# %%
journal_doc.plot_cumulative_sentiment()

# %%
journal_doc.describe()
# Out:
#              doc_name  word_count  sentence_count  \
# 0  sample_journal.txt        1338              70
#
#                                     longest_sentence most_common_word  \
# 0  Date: March 10, 2023  Today’s Tasks:  Write bl...                i
#
#    question_count  avg sentiment
# 0               1       0.297531
# {'doc_name': ['sample_journal.txt'],
#  'word_count': [1338],
#  'sentence_count': [70],
#  'longest_sentence': ['Date: March 10, 2023  Today’s Tasks:  Write blog post on journaling examples Schedule dentist appointment Complete 30-minute yoga session Attend team meeting at 2pm Respond to client emails Notes:  Remember to follow up with Sarah about the new project proposal Need to buy groceries after work – add to tomorrow’s task list The idea of my next art project keeps coming up.'],
#  'most_common_word': ['i'],
#  'question_count': [1],
#  'avg sentiment': [0.2975314285714286]}

# %%
journal_doc.find_most_common_word()
# Out:
# 'i'

# %%
journal_doc.find_longest_sentence()
# Out:
# 'Date: March 10, 2023  Today’s Tasks:  Write blog post on journaling examples Schedule dentist appointment Complete 30-minute yoga session Attend team meeting at 2pm Respond to client emails Notes:  Remember to follow up with Sarah about the new project proposal Need to buy groceries after work – add to tomorrow’s task list The idea of my next art project keeps coming up.'

# %%
journal_doc.sentences

# %%
import numpy as np

for _ in range(1, 10):
    rand_sentence_index = np.random.randint(len(journal_doc.sentences))
    print(journal_doc.sentences[rand_sentence_index].sentiment_score)
    print(journal_doc.sentences[rand_sentence_index].sentence_string)
# Out:
# 0.7579
# I walked along the Seine River, admiring the beautiful architecture of the buildings and bridges.
# 0.0
# Before bed, I took some time to reflect on the day.
# 0.0
# I believe that life is a journey of learning and self-discovery, and I always strive to grow and evolve as a person.
# 0.4404
# Overall, today was a good day.
# 0.128
# I believe that it’s essential to be truthful with myself and others, even when it’s difficult.
# 0.4404
# I couldn’t have predicted the delay, and I did the best I could under the circumstances.
# 0.7096
# One of my core values is honesty.
# -0.25
# I got stuck in heavy traffic on my way to work, and ended up arriving late.
# -0.1779
# As the day went on, my anxiety gradually subsided, and I was able to focus on my work and be productive.

# %%
journal_doc.sentences[rand_sentence_index].sentiment_score
journal_doc.sentences[rand_sentence_index].sentence_string
# Out:
# 'As the day went on, my anxiety gradually subsided, and I was able to focus on my work and be productive.'

# %%
journal_doc.sentences[2].sentence_string
# Out:
# 'The supportive friends and family in my life who are always there for me when I need them.'

# %%
journal_doc.sentences[2].word_tokens
# Out:
# ['The',
#  'supportive',
#  'friends',
#  'and',
#  'family',
#  'in',
#  'my',
#  'life',
#  'who',
#  'are',
#  'always',
#  'there',
#  'for',
#  'me',
#  'when',
#  'I',
#  'need',
#  'them']

# %%
journal_doc.sentences[2].remove_stopwords()

# %%
journal_doc.remove_stop_words(replace_document_string=True)

# %%
journal_doc.find_most_common_word()
# Out:
# 'day'

# %%
journal_doc.document_string
# Out:
# 'Date March 9 2023 Today grateful warm cup coffee morning helped start day right beautiful sunrise saw way work reminded beauty nature supportive friends family life always need fact job allows support pursue passions opportunity take walk outside lunch break soak sunshine fresh air Writing things grateful helps appreciate positive aspects life shifts focus away negativity reminds even toughest days still things grateful always something look forward tomorrow July 12 2022 Location Paris France Today first day Paris absolutely magical woke early headed straight Eiffel Tower catch sunrise view top breathtaking sun peeking horizon casting warm glow city breakfast local cafe spent rest day exploring city foot walked along Seine River admiring beautiful architecture buildings bridges stopped Notre Dame Cathedral stunning imagined afternoon visited Louvre Museum completely blown away art collection spent hours wandering galleries taking beauty history paintings sculptures day came close sa
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()



show_wordcloud(journal_doc.document_string)
